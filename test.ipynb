# %%
test_options={"1":"nono", "2":"jojo", "3":"koko"}

# %%
test_options.values()
# Out:
# dict_values(['nono', 'jojo', 'koko'])

# %%
import plotly.express as px

MEDAL_DATA = px.data.medals_long()
values=["China"]

# %%
filtered_data = MEDAL_DATA.query("nation in @values")
filtered_data
# Out:
#   nation   medal  count
# 1  China    gold     10
# 4  China  silver     15
# 7  China  bronze      8

# %%
import pathlib

# %%
import map_data as map_data

# %%
MAP_DATA = map_data.avg_data
GEO_DATA = map_data.geodata

# %%
values2 = [1013, 1019, 1021, 1024, 1025, 1033, 1034, 1035, 1051, 1052, 1053, 1055, 1056, 1057, 1058, 1059]

# %%
h
# Out:
# [1011,
#  1012,
#  1013,
#  1015,
#  1017,
#  1018,
#  1019,
#  1021,
#  1022,
#  1023,
#  1027,
#  1031,
#  1032,
#  1035,
#  1036,
#  1053,
#  1054,
#  1056,
#  1057,
#  1058,
#  1059,
#  1060,
#  1061,
#  1066,
#  1072,
#  1073,
#  1074,
#  1075,
#  1076,
#  1078,
#  1079,
#  1081,
#  1082,
#  1086,
#  1087,
#  1091,
#  1092,
#  1093,
#  1095,
#  1096,
#  1097,
#  1098,
#  1109]

# %%
int(GEO_DATA["features"][0]["properties"]["pc4_code"])
# Out:
# 3253

# %%
t = {'type': 'FeatureCollection', 'features': [GEO_DATA["features"][i] for i in range(0,len(GEO_DATA["features"])) if int(GEO_DATA["features"][i]["properties"]["pc4_code"]) in values2]}

# %%
t
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[4.865076630523455, 52.375710034618244],
#       [4.864792384749674, 52.37641990491732],
#       [4.863050500442789, 52.37617288483839],
#       [4.862855940903335, 52.376747959452025],
#       [4.86322008232952, 52.377767000948424],
#       [4.862865738105884, 52.378824185894125],
#       [4.860174491943566, 52.378438434997996],
#       [4.860061889308398, 52.378339551975735],
#       [4.858078511258491, 52.37810110473087],
#       [4.857103140072978, 52.37801407483201],
#       [4.857153326064283, 52.37786224917588],
#       [4.85501797242787, 52.377611752492626],
#       [4.855315355061975, 52.37665340663329],
#       [4.855661793316844, 52.375536929460054],
#       [4.855918405377277, 52.37536897014957],
#       [4.855188560946805, 52.375258565678486],
#       [4.854605518104553, 52.375073508900776],
#       [4.853129278608153, 52.376015983300135],
# ...

# %%
testval = [[1011, 1012, 1013, 1014, 1015, 1016, 1017, 1018, 1019, 1021, 1022, 1023, 1024, 1025, 1027, 1028, 1031, 1032, 1033, 1034, 1035, 1036, 1051, 1052, 1053, 1054, 1055, 1056, 1057, 1058, 1059, 1060, 1061, 1062, 1063, 1064, 1065, 1066, 1067, 1068, 1069, 1071, 1072, 1073, 1074, 1075, 1076, 1077, 1078, 1079, 1081, 1082, 1083, 1086, 1087, 1091, 1092, 1093, 1094, 1095, 1096, 1097, 1098, 1102, 1103, 1104, 1106, 1107, 1108, 1109]]
values = [400000, 900000]
h = list(MAP_DATA.query("Price > @values[0] & Price < @values[1]")["Region"])
h
# Out:
# [1011,
#  1012,
#  1013,
#  1015,
#  1017,
#  1018,
#  1019,
#  1021,
#  1022,
#  1023,
#  1027,
#  1031,
#  1032,
#  1035,
#  1036,
#  1053,
#  1054,
#  1056,
#  1057,
#  1058,
#  1059,
#  1060,
#  1061,
#  1066,
#  1072,
#  1073,
#  1074,
#  1075,
#  1076,
#  1078,
#  1079,
#  1081,
#  1082,
#  1086,
#  1087,
#  1091,
#  1092,
#  1093,
#  1095,
#  1096,
#  1097,
#  1098,
#  1109]

# %%
# Out:
# [1035, 1012, 1011]

# %%
BIN_DATA.loc[BIN_DATA["Region"] == 1017, "Price_Region"]
# Out:
# 11    less_600000
# Name: Price_Region, dtype: object

# %%
import pandas as pd

data = pd.read_csv(".\HousingPrices-Amsterdam-August-2021.csv")
data["Region"] = data["Zip"].str[0:4].astype(int)
data
# Out:
#      Unnamed: 0                                 Address      Zip     Price  \
# 0             1            Blasiusstraat 8 2, Amsterdam  1091 CR  685000.0
# 1             2  Kromme Leimuidenstraat 13 H, Amsterdam  1059 EL  475000.0
# 2             3              Zaaiersweg 11 A, Amsterdam  1097 SM  850000.0
# 3             4            Tenerifestraat 40, Amsterdam  1060 TH  580000.0
# 4             5              Winterjanpad 21, Amsterdam  1036 KN  720000.0
# ..          ...                                     ...      ...       ...
# 919         920                     Ringdijk, Amsterdam  1097 AE  750000.0
# 920         921         Kleine Beerstraat 31, Amsterdam  1033 CP  350000.0
# 921         922       Stuyvesantstraat 33 II, Amsterdam  1058 AK  350000.0
# 922         923   John Blankensteinstraat 51, Amsterdam  1095 MB  599000.0
# 923         924      S. F. van Ossstraat 334, Amsterdam  1068 JS  300000.0
#
#      Area  Room       Lon        Lat  Region
# ...

# %%
t = [x for x in MAP_DATA]
t
# Out:
# ['Region', 'Price']
